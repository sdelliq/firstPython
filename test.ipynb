# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Users/sophia.dellarciprete/Documents/CorsoPython/DATATAPE_ANNIA.xlsx')
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0        NDG   Category      Group
# 1     116648      SOFF.          -
# 2     130039      SOFF.          -
# 3    2238193      SOFF.          -
# 4   11700732      SOFF.          -
#
#                                           Unnamed: 3  \
# 0                                       BorrowerName
# 1                                 MARKET NALIN S.R.L
# 2                                DOMUS BRENTA S.R.L.
# 3  MARETTO TOBIA, MARETTO MARTINO, MARETTO RINO, ...
# 4                                         NAI FRANCO
#
#                                           Unnamed: 4  \
# 0                                             Tax ID
# 1                                         4692690284
# 2                                         2221113876
# 3  MRTTBO64B19G565F , MRTMTN73E09D325H , MRTRFL68...
# 4                                   NAIFNC45H21A296Y
#
#                       Unnamed: 5              Unnamed: 6 Unnamed: 7  \
# 0                        Address                    Town       City
# 1             VIA PADOVA, N. 108                 CARTURA     PADOVA
# 2                VIA POLA, N. 30     TORRI DI QUARTESOLO    VICENZA
# 3  VIA DON S. FERRONATO, N. 49/2                 PIANIGA    VENEZIA
# 4    VIA GUGLIELMO MARCONI, 1084  SAN MARTINO DI VENEZZE     ROVIGO
#
#           Unnamed: 8
# 0  Borrower's Region
# 1             VENETO
# 2             VENETO
# 3             VENETO
# 4             VENETO

# %%
df.columns = df.iloc[0] # Set the first row as column names
df = df[1:]
df.head()
# Out:
# 0       NDG Category Group                                       BorrowerName  \
# 1    116648    SOFF.     -                                 MARKET NALIN S.R.L
# 2    130039    SOFF.     -                                DOMUS BRENTA S.R.L.
# 3   2238193    SOFF.     -  MARETTO TOBIA, MARETTO MARTINO, MARETTO RINO, ...
# 4  11700732    SOFF.     -                                         NAI FRANCO
# 5    128408    SOFF.     -        MIEN RAPPRESENTANZE SNC DI BERNARDI MICHELE
#
# 0                                             Tax ID  \
# 1                                         4692690284
# 2                                         2221113876
# 3  MRTTBO64B19G565F , MRTMTN73E09D325H , MRTRFL68...
# 4                                   NAIFNC45H21A296Y
# 5                                         4667240289
#
# 0                        Address                    Town     City  \
# 1             VIA PADOVA, N. 108                 CARTURA   PADOVA
# 2                VIA POLA, N. 30     TORRI DI QUARTESOLO  VICENZA
# 3  VIA DON S. FERRONATO, N. 49/2                 PIANIGA  VENEZIA
# 4    VIA GUGLIELMO MARCONI, 1084  SAN MARTINO DI VENEZZE   ROVIGO
# 5              VIA CAVOUR, N. 32                 VIGONZA   PADOVA
#
# 0 Borrower's Region
# 1            VENETO
# 2            VENETO
# 3            VENETO
# 4            VENETO
# 5            VENETO

# %%
df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
# 0        NDG Category                   Group  \
# 1     116648    soff.                       -
# 2     130039    soff.                       -
# 3    2238193    soff.                       -
# 4   11700732    soff.                       -
# 5     128408    soff.                       -
# 6     129281    soff.                       -
# 7     135407      utp                       -
# 8     164108      utp                       -
# 9    2283104      utp                       -
# 10   2175415    soff.  gruppo boscolo/tuzzato
# 11   2294916    soff.  gruppo boscolo/tuzzato
#
# 0                                        BorrowerName  \
# 1                                  market nalin s.r.l
# 2                                 domus brenta s.r.l.
# 3   maretto tobia, maretto martino, maretto rino, ...
# 4                                          nai franco
# 5         mien rappresentanze snc di bernardi michele
# 6                  zerbinati elisa - montagnana fabio
# 7                                           grace srl
# 8                               suolificio stema srls
# 9                           nicolin fernanda giovanna
# 10                             trattoria nalin s.r.l.
# 11  immobiliare spes di tuzzato francesco societa'...
#
# 0                                              Tax ID  \
# 1                                          4692690284
# 2                                          2221113876
# 3   mrttbo64b19g565f , mrtmtn73e09d325h , mrtrfl68...
# 4                                    naifnc45h21a296y
# 5                                          4667240289
# 6                 zrblse83h52a539x , mntfba80e23a539u
# 7                                          5098280281
# 8                                          4511170278
# 9                                    nclfnn83c46z602z
# 10                                         1846720272
# 11                                         1817560277
#
# 0                           Address                    Town     City  \
# 1                via padova, n. 108                 cartura   padova
# 2                   via pola, n. 30     torri di quartesolo  vicenza
# 3     via don s. ferronato, n. 49/2                 pianiga  venezia
# 4       via guglielmo marconi, 1084  san martino di venezze   rovigo
# 5                 via cavour, n. 32                 vigonza   padova
# 6           via ponte alto, n. 26/a         pojana maggiore   rovigo
# 7             via p. kolbe, n. 62/b        noventa padovana   padova
# 8              via giudecca, n. 2/4                  mirano  venezia
# 9               via ballò, n. 115/a                  mirano  venezia
# 10  via argine sx nuovissimo, n. 29                    mira  venezia
# 11         piazza g. marconi, n. 25                    stra  venezia
#
# 0  Borrower's Region
# 1             veneto
# 2             veneto
# 3             veneto
# 4             veneto
# 5             veneto
# 6             veneto
# 7             veneto
# 8             veneto
# 9             veneto
# 10            veneto
# 11            veneto

# %%
df.head()
# Out:
# 0       NDG Category Group                                       BorrowerName  \
# 1    116648    soff.     -                                 market nalin s.r.l
# 2    130039    soff.     -                                domus brenta s.r.l.
# 3   2238193    soff.     -  maretto tobia, maretto martino, maretto rino, ...
# 4  11700732    soff.     -                                         nai franco
# 5    128408    soff.     -        mien rappresentanze snc di bernardi michele
#
# 0                                             Tax ID  \
# 1                                         4692690284
# 2                                         2221113876
# 3  mrttbo64b19g565f , mrtmtn73e09d325h , mrtrfl68...
# 4                                   naifnc45h21a296y
# 5                                         4667240289
#
# 0                        Address                    Town     City  \
# 1             via padova, n. 108                 cartura   padova
# 2                via pola, n. 30     torri di quartesolo  vicenza
# 3  via don s. ferronato, n. 49/2                 pianiga  venezia
# 4    via guglielmo marconi, 1084  san martino di venezze   rovigo
# 5              via cavour, n. 32                 vigonza   padova
#
# 0 Borrower's Region
# 1            veneto
# 2            veneto
# 3            veneto
# 4            veneto
# 5            veneto
