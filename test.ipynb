# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Users/sophia.dellarciprete/Documents/CorsoPython/DATATAPE_ANNIA.xlsx')
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0        NDG   Category      Group
# 1     116648      SOFF.          -
# 2     130039      SOFF.          -
# 3    2238193      SOFF.          -
# 4   11700732      SOFF.          -
#
#                                           Unnamed: 3  \
# 0                                       BorrowerName
# 1                                 MARKET NALIN S.R.L
# 2                                DOMUS BRENTA S.R.L.
# 3  MARETTO TOBIA, MARETTO MARTINO, MARETTO RINO, ...
# 4                                         NAI FRANCO
#
#                                           Unnamed: 4  \
# 0                                             Tax ID
# 1                                         4692690284
# 2                                         2221113876
# 3  MRTTBO64B19G565F , MRTMTN73E09D325H , MRTRFL68...
# 4                                   NAIFNC45H21A296Y
#
#                       Unnamed: 5              Unnamed: 6 Unnamed: 7  \
# ...
